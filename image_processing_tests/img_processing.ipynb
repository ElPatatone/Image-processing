# %%
from skimage import io, img_as_ubyte, color
import matplotlib.pyplot as plt
import matplotlib.image as mpimg 
import numpy as np
from scipy import ndimage

# %%
img = mpimg.imread("images/cute_cat.jpg")  #this is a numpy array

print(img.shape)

#printing out the cute cat
plt.imshow(img)
# Out:
# (1080, 1080, 3)

# %%
#turning the image into greyscale
imgGray = color.rgb2gray(img)
plt.imshow(imgGray)

# %%
#showing the image using matplotlib results in a colored ia
