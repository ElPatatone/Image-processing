# %%
from skimage import io, img_as_ubyte
import matplotlib.pyplot as plt
import matplotlib.image as mpimg 
import numpy as np
from scipy import ndimage

# %%
img = mpimg.imread("images/cute_cat.jpg")  #this is a numpy array
print(type(img))

print(img.shape)

#printing out the cute cat
plt.imshow(img)
# Out:
# <class 'numpy.ndarray'>
# (1080, 1080, 3)

# %%
img2 = img_as_ubyte(io.imread("images/cute_cat.jpg", as_gray=True))
plt.imshow(img2)
